# %%
   +-----------------+
   |      Start      |
   +-----------------+
           |
           v
   +-----------------+
   |  Input P, R, T  |
   +-----------------+
           |
           v
   +-------------------------------------+
   |  A = P * (1 + (R / 100) * T)        |
   +-------------------------------------+
           |
           v
   +-----------------+
   |  Print A        |
   +-----------------+
           |
           v
   +-----------------+
   |      End        |
   +-----------------+

# %%
   +-----------------+
   |      Start      |
   +-----------------+
           |
           v
   +-------------------------+
   |  Input P, R, n, t       |
   +-------------------------+
           |
           v
   +------------------------------------------------------+
   |  A = P * (1 + (R / (n * 100))) ^ (n * t)             |
   +------------------------------------------------------+
           |
           v
   +-----------------+
   |  Print A        |
   +-----------------+
           |
           v
   +-----------------+
   |      End        |
   +-----------------+

# %%
   +-----------------+
   |      Start      |
   +-----------------+
           |
           v
   +-----------------------------+
   |  Input PMT, R, n, t         |
   +-----------------------------+
           |
           v
   +------------------------------------------------------------+
   |  A = PMT * (((1 + R/n)^(n*t) - 1) / (R/n))                 |
   +------------------------------------------------------------+
           |
           v
   +-----------------+
   |  Print A        |
   +-----------------+
           |
           v
   +-----------------+
   |      End        |
   +-----------------+
